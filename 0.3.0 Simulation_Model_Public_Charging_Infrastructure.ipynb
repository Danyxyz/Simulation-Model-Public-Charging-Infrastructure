# %%
import json
import pandas as pd
import re
import requests


#JSON File für die Ladestationen als speichern
url = "https://data.geo.admin.ch/ch.bfe.ladestellen-elektromobilitaet/data/oicp/ch.bfe.ladestellen-elektromobilitaet.json"


#Daten mittels REST GET request holen
data = requests.get(url)

#Daten als JSON File speichern
data_orig = data.json()

# Read the data
#data_orig = json.load(open('ch.bfe.ladestellen-elektromobilitaet.json', 
#                           encoding='utf-8'))

# Save the data as pandas data frame
data = pd.DataFrame(data_orig["EVSEData"])

# Getting the index of evpass
idx = data[data["OperatorName"].isin(['evpass'])].index[0]

# Create data frame from column 'EVSEDataRecord' in the subset
df = pd.DataFrame(data.loc[idx, 'EVSEDataRecord'])


# Look at the geo-coordinates (latitude and longitude)
coordinates = df.GeoCoordinates

# Getting single values from as string
coord_str = "".join(coordinates[0].values())

# Splitting string by white space
re.findall(r'\S+', coord_str)

# Now loop though the coordinates object
out_list = []
for i in coordinates:
    # Getting single values from as string
    coord_str = "".join(i.values())
    # Splitting string by white space
    coords = re.findall(r'\S+', coord_str)
    out_list.append(coords)
    

# Create data frame from the list
df = pd.DataFrame(out_list, columns =['Latitude', 'Longitude'])

# Here we have still strings of the which need to be converted to integers

# First: exclude white space using pythons lambda function
df['Latitude'] = df['Latitude'].apply(lambda x: x.strip())
df['Longitude'] = df['Longitude'].apply(lambda x: x.strip())

# Second: cange to integer values
df['Latitude'] = df['Latitude'].astype(float)
df['Longitude'] =  df['Longitude'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-686ec22ad016> in <module>
#      34
#      35 # Look at the geo-coordinates (latitude and longitude)
# ---> 36 coordinates = df.GeoCoordinates
#      37
#      38 # Getting single values from as string
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'GeoCoordinates'

# %%
import folium

m = folium.Map(location=[46.4754, 8.1355], zoom_start = 7)

#Loop trough datasets and set a marker for every charging station from the bfe dataset
#for i in range(len(df)):
#    x = df.Latitude[i]
#    y = df.Longitude[i]
#    folium.Marker(
#    [x, y]).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_2ea7f0df071d480eb68e8773822d8e6e%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_2ea7f0df071d480eb68e8773822d8e6e%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_2ea7f0df071d480eb68e8773822d8e6e%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_2ea7f0df071d480eb68e8773822d8e6e%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B46.4754%2C%208.1355%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
import requests
import json

url = "https://api3.geo.admin.ch/rest/services/profile.json"

params = {
 "searchField": "zip_label",
 "searchText": "3011"
} 

response = requests.get(url=url, params=params)
print("URL:" + response.url)
print("Output: \n " + json.dumps(response.json(), indent=2, ensure_ascii=0))
# Out:
# URL:https://api3.geo.admin.ch/rest/services/profile.json?searchField=zip_label&searchText=3011
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-76-21246e3c9a36> in <module>
#      11 response = requests.get(url=url, params=params)
#      12 print("URL:" + response.url)
# ---> 13 print("Output: \n " + json.dumps(response.json(), indent=2, ensure_ascii=0))
#      14
#
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     338         end = _w(s, end).end()
#     339         if end != len(s):
# --> 340             raise JSONDecodeError("Extra data", s, end)
#     341         return obj
#     342
#
# JSONDecodeError: Extra data: line 1 column 5 (char 4)

# %%
import json
import requests
url = r"https://api3.geo.admin.ch/rest/services/api/MapServer/find"
params = {
 "layer": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
 "searchField": "stn_label",
 "searchText": "A", "geometryFormat": "", "returnGeometry":""
}
response = requests.get(url=url, params=params)
print("URL:" + response.url)
print("Output: \n " + json.dumps(response.json(), indent=2, ensure_ascii=0))
# Out:
# URL:https://api3.geo.admin.ch/rest/services/api/MapServer/find?layer=ch.swisstopo.amtliches-gebaeudeadressverzeichnis&searchField=stn_label&searchText=A&geometryFormat=&returnGeometry=
# Output:
#  {
#   "results": [
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100343265,
#       "geometry": {
#         "y": 266935.1,
#         "x": 609533.5,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         609533.5,
#         266935.1,
#         609533.5,
#         266935.1
#       ],
#       "attributes": {
#         "adr_number": "110",
#         "com_fosnr": 2701,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4054 Basel",
#         "adr_egaid": 100343265,
#         "adr_edid": 0,
#         "label": 100343265,
#         "bdg_egid": 450735,
#         "stn_label": "Morgartenring",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10025038,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100343265
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100267245,
#       "geometry": {
#         "y": 267691.7,
#         "x": 609997.8,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         609997.8,
#         267691.7,
#         609997.8,
#         267691.7
#       ],
#       "attributes": {
#         "adr_number": "49",
#         "com_fosnr": 2701,
#         "bdg_category": "other_residential",
#         "adr_modified": "20210126",
#         "zip_label": "4055 Basel",
#         "adr_egaid": 100267245,
#         "adr_edid": 0,
#         "label": 100267245,
#         "bdg_egid": 451334,
#         "stn_label": "Colmarerstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10025632,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100267245
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100341625,
#       "geometry": {
#         "y": 268502.2,
#         "x": 613363.0,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         613363.0,
#         268502.2,
#         613363.0,
#         268502.2
#       ],
#       "attributes": {
#         "adr_number": "31",
#         "com_fosnr": 2701,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4058 Basel",
#         "adr_egaid": 100341625,
#         "adr_edid": 0,
#         "label": 100341625,
#         "bdg_egid": 455917,
#         "stn_label": "Hirzbrunnenschanze",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10087624,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100341625
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 102423080,
#       "geometry": {
#         "y": 269481.5,
#         "x": 614659.4,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         614659.4,
#         269481.5,
#         614659.4,
#         269481.5
#       ],
#       "attributes": {
#         "adr_number": "266.2",
#         "com_fosnr": 2703,
#         "bdg_category": "non_residential",
#         "adr_modified": "20220325",
#         "zip_label": "4125 Riehen",
#         "adr_egaid": 102423080,
#         "adr_edid": 0,
#         "label": 102423080,
#         "bdg_egid": 243057937,
#         "stn_label": "Aeussere Baselstrasse",
#         "adr_official": false,
#         "adr_status": "real",
#         "str_esid": 10024820,
#         "com_name": "Riehen"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 102423080
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 101436964,
#       "geometry": {
#         "y": 270807.9,
#         "x": 614864.5,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         614864.5,
#         270807.9,
#         614864.5,
#         270807.9
#       ],
#       "attributes": {
#         "adr_number": "110",
#         "com_fosnr": 2703,
#         "bdg_category": "non_residential",
#         "adr_modified": "20210126",
#         "zip_label": "4125 Riehen",
#         "adr_egaid": 101436964,
#         "adr_edid": 0,
#         "label": 101436964,
#         "bdg_egid": 459177,
#         "stn_label": "Weilmattweg",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10068285,
#         "com_name": "Riehen"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 101436964
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100297699,
#       "geometry": {
#         "y": 267811.3,
#         "x": 610456.9,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         610456.9,
#         267811.3,
#         610456.9,
#         267811.3
#       ],
#       "attributes": {
#         "adr_number": "55",
#         "com_fosnr": 2701,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4056 Basel",
#         "adr_egaid": 100297699,
#         "adr_edid": 0,
#         "label": 100297699,
#         "bdg_egid": 441240,
#         "stn_label": "Maiengasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10026487,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100297699
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100327831,
#       "geometry": {
#         "y": 267856.2,
#         "x": 609644.8,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         609644.8,
#         267856.2,
#         609644.8,
#         267856.2
#       ],
#       "attributes": {
#         "adr_number": "25",
#         "com_fosnr": 2701,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4055 Basel",
#         "adr_egaid": 100327831,
#         "adr_edid": 0,
#         "label": 100327831,
#         "bdg_egid": 451686,
#         "stn_label": "Blotzheimerstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10120973,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100327831
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 101301804,
#       "geometry": {
#         "y": 267276.3,
#         "x": 611073.2,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         611073.2,
#         267276.3,
#         611073.2,
#         267276.3
#       ],
#       "attributes": {
#         "adr_number": "35",
#         "com_fosnr": 2701,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4051 Basel",
#         "adr_egaid": 101301804,
#         "adr_edid": 1,
#         "label": 101301804,
#         "bdg_egid": 440300,
#         "stn_label": "Leonhardsgraben",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10025926,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 101301804
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 102434654,
#       "geometry": {
#         "y": 266027.2,
#         "x": 609929.3,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         609929.3,
#         266027.2,
#         609929.3,
#         266027.2
#       ],
#       "attributes": {
#         "adr_number": "77.1",
#         "com_fosnr": 2701,
#         "bdg_category": "non_residential",
#         "adr_modified": "20220325",
#         "zip_label": "4054 Basel",
#         "adr_egaid": 102434654,
#         "adr_edid": 0,
#         "label": 102434654,
#         "bdg_egid": 243055768,
#         "stn_label": "Holeestrasse",
#         "adr_official": false,
#         "adr_status": "real",
#         "str_esid": 10063528,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 102434654
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100343343,
#       "geometry": {
#         "y": 267606.7,
#         "x": 612125.0,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         612125.0,
#         267606.7,
#         612125.0,
#         267606.7
#       ],
#       "attributes": {
#         "adr_number": "13",
#         "com_fosnr": 2701,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4058 Basel",
#         "adr_egaid": 100343343,
#         "adr_edid": 0,
#         "label": 100343343,
#         "bdg_egid": 454632,
#         "stn_label": "Grenzacherstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10087623,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100343343
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100260903,
#       "geometry": {
#         "y": 269115.1,
#         "x": 612942.6,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         612942.6,
#         269115.1,
#         612942.6,
#         269115.1
#       ],
#       "attributes": {
#         "adr_number": "3",
#         "com_fosnr": 2701,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4058 Basel",
#         "adr_egaid": 100260903,
#         "adr_edid": 0,
#         "label": 100260903,
#         "bdg_egid": 455289,
#         "stn_label": "An der hohlen Gasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10087621,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100260903
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 102435804,
#       "geometry": {
#         "y": 269321.4,
#         "x": 612687.2,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         612687.2,
#         269321.4,
#         612687.2,
#         269321.4
#       ],
#       "attributes": {
#         "adr_number": "110.13",
#         "com_fosnr": 2701,
#         "bdg_category": "non_residential",
#         "adr_modified": "20220325",
#         "zip_label": "4058 Basel",
#         "adr_egaid": 102435804,
#         "adr_edid": 0,
#         "label": 102435804,
#         "bdg_egid": 243057580,
#         "stn_label": "Erlenparkweg",
#         "adr_official": false,
#         "adr_status": "real",
#         "str_esid": 10025636,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 102435804
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100294968,
#       "geometry": {
#         "y": 265503.2,
#         "x": 612348.5,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         612348.5,
#         265503.2,
#         612348.5,
#         265503.2
#       ],
#       "attributes": {
#         "adr_number": "52",
#         "com_fosnr": 2701,
#         "bdg_category": "other_residential",
#         "adr_modified": "20210126",
#         "zip_label": "4053 Basel",
#         "adr_egaid": 100294968,
#         "adr_edid": 0,
#         "label": 100294968,
#         "bdg_egid": 445472,
#         "stn_label": "Reinacherstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10025943,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100294968
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100335405,
#       "geometry": {
#         "y": 266442.6,
#         "x": 612877.1,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         612877.1,
#         266442.6,
#         612877.1,
#         266442.6
#       ],
#       "attributes": {
#         "adr_number": "211",
#         "com_fosnr": 2701,
#         "bdg_category": "other_residential",
#         "adr_modified": "20210126",
#         "zip_label": "4052 Basel",
#         "adr_egaid": 100335405,
#         "adr_edid": 0,
#         "label": 100335405,
#         "bdg_egid": 443978,
#         "stn_label": "St. Alban-Ring",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10187914,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100335405
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100346962,
#       "geometry": {
#         "y": 268877.0,
#         "x": 615909.4,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         615909.4,
#         268877.0,
#         615909.4,
#         268877.0
#       ],
#       "attributes": {
#         "adr_number": "8",
#         "com_fosnr": 2703,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4125 Riehen",
#         "adr_egaid": 100346962,
#         "adr_edid": 0,
#         "label": 100346962,
#         "bdg_egid": 460134,
#         "stn_label": "Höhenstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10086298,
#         "com_name": "Riehen"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100346962
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100296510,
#       "geometry": {
#         "y": 267239.7,
#         "x": 610371.6,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         610371.6,
#         267239.7,
#         610371.6,
#         267239.7
#       ],
#       "attributes": {
#         "adr_number": "58",
#         "com_fosnr": 2701,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4051 Basel",
#         "adr_egaid": 100296510,
#         "adr_edid": 0,
#         "label": 100296510,
#         "bdg_egid": 441694,
#         "stn_label": "Socinstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10026769,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100296510
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100261609,
#       "geometry": {
#         "y": 268376.9,
#         "x": 611623.0,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         611623.0,
#         268376.9,
#         611623.0,
#         268376.9
#       ],
#       "attributes": {
#         "adr_number": "50",
#         "com_fosnr": 2701,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4057 Basel",
#         "adr_egaid": 100261609,
#         "adr_edid": 0,
#         "label": 100261609,
#         "bdg_egid": 457442,
#         "stn_label": "Müllheimerstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10088578,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100261609
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100265453,
#       "geometry": {
#         "y": 266564.5,
#         "x": 609101.6,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         609101.6,
#         266564.5,
#         609101.6,
#         266564.5
#       ],
#       "attributes": {
#         "adr_number": "68",
#         "com_fosnr": 2701,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4054 Basel",
#         "adr_egaid": 100265453,
#         "adr_edid": 0,
#         "label": 100265453,
#         "bdg_egid": 449316,
#         "stn_label": "Paradieshofstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10025040,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100265453
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100331365,
#       "geometry": {
#         "y": 267398.0,
#         "x": 609989.3,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         609989.3,
#         267398.0,
#         609989.3,
#         267398.0
#       ],
#       "attributes": {
#         "adr_number": "2",
#         "com_fosnr": 2701,
#         "bdg_category": "other_residential",
#         "adr_modified": "20210126",
#         "zip_label": "4055 Basel",
#         "adr_egaid": 100331365,
#         "adr_edid": 0,
#         "label": 100331365,
#         "bdg_egid": 450062,
#         "stn_label": "Allschwilerplatz",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10025623,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100331365
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 101338159,
#       "geometry": {
#         "y": 266138.1,
#         "x": 609904.7,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         609904.7,
#         266138.1,
#         609904.7,
#         266138.1
#       ],
#       "attributes": {
#         "adr_number": "7",
#         "com_fosnr": 2701,
#         "bdg_category": "non_residential",
#         "adr_modified": "20210126",
#         "zip_label": "4054 Basel",
#         "adr_egaid": 101338159,
#         "adr_edid": 0,
#         "label": 101338159,
#         "bdg_egid": 243009962,
#         "stn_label": "Nenzlingerstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10179469,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 101338159
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 101723935,
#       "geometry": {
#         "y": 266874.7,
#         "x": 611022.5,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         611022.5,
#         266874.7,
#         611022.5,
#         266874.7
#       ],
#       "attributes": {
#         "adr_number": "4",
#         "com_fosnr": 2701,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4051 Basel",
#         "adr_egaid": 101723935,
#         "adr_edid": 0,
#         "label": 101723935,
#         "bdg_egid": 243053508,
#         "stn_label": "Auberg",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10122246,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 101723935
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100265900,
#       "geometry": {
#         "y": 268793.2,
#         "x": 613347.7,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         613347.7,
#         268793.2,
#         613347.7,
#         268793.2
#       ],
#       "attributes": {
#         "adr_number": "318",
#         "com_fosnr": 2701,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4058 Basel",
#         "adr_egaid": 100265900,
#         "adr_edid": 0,
#         "label": 100265900,
#         "bdg_egid": 455475,
#         "stn_label": "Riehenstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10088584,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100265900
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100344881,
#       "geometry": {
#         "y": 268888.7,
#         "x": 611600.2,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         611600.2,
#         268888.7,
#         611600.2,
#         268888.7
#       ],
#       "attributes": {
#         "adr_number": "40",
#         "com_fosnr": 2701,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4057 Basel",
#         "adr_egaid": 100344881,
#         "adr_edid": 0,
#         "label": 100344881,
#         "bdg_egid": 457857,
#         "stn_label": "Horburgstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10107050,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100344881
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100323669,
#       "geometry": {
#         "y": 264431.1,
#         "x": 612222.0,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         612222.0,
#         264431.1,
#         612222.0,
#         264431.1
#       ],
#       "attributes": {
#         "adr_number": "1",
#         "com_fosnr": 2701,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4059 Basel",
#         "adr_egaid": 100323669,
#         "adr_edid": 0,
#         "label": 100323669,
#         "bdg_egid": 447135,
#         "stn_label": "Birseckstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10179481,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100323669
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 101619750,
#       "geometry": {
#         "y": 270505.8,
#         "x": 612013.3,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         612013.3,
#         270505.8,
#         612013.3,
#         270505.8
#       ],
#       "attributes": {
#         "adr_number": "57",
#         "com_fosnr": 2701,
#         "bdg_category": "non_residential",
#         "adr_modified": "20210126",
#         "zip_label": "4057 Basel",
#         "adr_egaid": 101619750,
#         "adr_edid": 0,
#         "label": 101619750,
#         "bdg_egid": 243020017,
#         "stn_label": "Südquaistrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10026512,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 101619750
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100334740,
#       "geometry": {
#         "y": 267792.7,
#         "x": 609732.1,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         609732.1,
#         267792.7,
#         609732.1,
#         267792.7
#       ],
#       "attributes": {
#         "adr_number": "114",
#         "com_fosnr": 2701,
#         "bdg_category": "other_residential",
#         "adr_modified": "20210126",
#         "zip_label": "4055 Basel",
#         "adr_egaid": 100334740,
#         "adr_edid": 0,
#         "label": 100334740,
#         "bdg_egid": 452003,
#         "stn_label": "Strassburgerallee",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10087603,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100334740
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100266336,
#       "geometry": {
#         "y": 266162.9,
#         "x": 608973.8,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         608973.8,
#         266162.9,
#         608973.8,
#         266162.9
#       ],
#       "attributes": {
#         "adr_number": "100",
#         "com_fosnr": 2701,
#         "bdg_category": "other_residential",
#         "adr_modified": "20210126",
#         "zip_label": "4054 Basel",
#         "adr_egaid": 100266336,
#         "adr_edid": 0,
#         "label": 100266336,
#         "bdg_egid": 449750,
#         "stn_label": "Neuweilerstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10120297,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100266336
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100299672,
#       "geometry": {
#         "y": 265602.6,
#         "x": 612214.0,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         612214.0,
#         265602.6,
#         612214.0,
#         265602.6
#       ],
#       "attributes": {
#         "adr_number": "295",
#         "com_fosnr": 2701,
#         "bdg_category": "other_residential",
#         "adr_modified": "20210126",
#         "zip_label": "4053 Basel",
#         "adr_egaid": 100299672,
#         "adr_edid": 0,
#         "label": 100299672,
#         "bdg_egid": 445218,
#         "stn_label": "Güterstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10128630,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100299672
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100327828,
#       "geometry": {
#         "y": 267857.7,
#         "x": 609665.3,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         609665.3,
#         267857.7,
#         609665.3,
#         267857.7
#       ],
#       "attributes": {
#         "adr_number": "19",
#         "com_fosnr": 2701,
#         "bdg_category": "other_residential",
#         "adr_modified": "20210126",
#         "zip_label": "4055 Basel",
#         "adr_egaid": 100327828,
#         "adr_edid": 0,
#         "label": 100327828,
#         "bdg_egid": 451682,
#         "stn_label": "Blotzheimerstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10120973,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100327828
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100262254,
#       "geometry": {
#         "y": 266738.8,
#         "x": 610387.6,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         610387.6,
#         266738.8,
#         610387.6,
#         266738.8
#       ],
#       "attributes": {
#         "adr_number": "37",
#         "com_fosnr": 2701,
#         "bdg_category": "other_residential",
#         "adr_modified": "20210126",
#         "zip_label": "4051 Basel",
#         "adr_egaid": 100262254,
#         "adr_edid": 0,
#         "label": 100262254,
#         "bdg_egid": 447531,
#         "stn_label": "Arnold Böcklin-Strasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10025347,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100262254
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100332468,
#       "geometry": {
#         "y": 267940.0,
#         "x": 609559.7,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         609559.7,
#         267940.0,
#         609559.7,
#         267940.0
#       ],
#       "attributes": {
#         "adr_number": "30",
#         "com_fosnr": 2701,
#         "bdg_category": "other_residential",
#         "adr_modified": "20210126",
#         "zip_label": "4055 Basel",
#         "adr_egaid": 100332468,
#         "adr_edid": 0,
#         "label": 100332468,
#         "bdg_egid": 451704,
#         "stn_label": "Blotzheimerstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10120973,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100332468
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100345033,
#       "geometry": {
#         "y": 269001.7,
#         "x": 611861.8,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         611861.8,
#         269001.7,
#         611861.8,
#         269001.7
#       ],
#       "attributes": {
#         "adr_number": "93",
#         "com_fosnr": 2701,
#         "bdg_category": "other_residential",
#         "adr_modified": "20210126",
#         "zip_label": "4057 Basel",
#         "adr_egaid": 100345033,
#         "adr_edid": 0,
#         "label": 100345033,
#         "bdg_egid": 457997,
#         "stn_label": "Horburgstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10107050,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100345033
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100347748,
#       "geometry": {
#         "y": 268308.6,
#         "x": 613119.3,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         613119.3,
#         268308.6,
#         613119.3,
#         268308.6
#       ],
#       "attributes": {
#         "adr_number": "46",
#         "com_fosnr": 2701,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4058 Basel",
#         "adr_egaid": 100347748,
#         "adr_edid": 0,
#         "label": 100347748,
#         "bdg_egid": 456093,
#         "stn_label": "Paracelsusstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10025102,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100347748
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 102434798,
#       "geometry": {
#         "y": 268877.1,
#         "x": 613800.4,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         613800.4,
#         268877.1,
#         613800.4,
#         268877.1
#       ],
#       "attributes": {
#         "adr_number": "394.1",
#         "com_fosnr": 2701,
#         "bdg_category": "non_residential",
#         "adr_modified": "20220325",
#         "zip_label": "4058 Basel",
#         "adr_egaid": 102434798,
#         "adr_edid": 0,
#         "label": 102434798,
#         "bdg_egid": 243056971,
#         "stn_label": "Riehenstrasse",
#         "adr_official": false,
#         "adr_status": "real",
#         "str_esid": 10088584,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 102434798
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 102436511,
#       "geometry": {
#         "y": 269462.1,
#         "x": 611596.6,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         611596.6,
#         269462.1,
#         611596.6,
#         269462.1
#       ],
#       "attributes": {
#         "adr_number": "46.2",
#         "com_fosnr": 2701,
#         "bdg_category": "non_residential",
#         "adr_modified": "20220325",
#         "zip_label": "4057 Basel",
#         "adr_egaid": 102436511,
#         "adr_edid": 0,
#         "label": 102436511,
#         "bdg_egid": 243056218,
#         "stn_label": "Gärtnerstrasse",
#         "adr_official": false,
#         "adr_status": "real",
#         "str_esid": 10179476,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 102436511
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 101336535,
#       "geometry": {
#         "y": 266240.0,
#         "x": 609573.3,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         609573.3,
#         266240.0,
#         609573.3,
#         266240.0
#       ],
#       "attributes": {
#         "adr_number": "6",
#         "com_fosnr": 2701,
#         "bdg_category": "non_residential",
#         "adr_modified": "20210126",
#         "zip_label": "4054 Basel",
#         "adr_egaid": 101336535,
#         "adr_edid": 0,
#         "label": 101336535,
#         "bdg_egid": 243006121,
#         "stn_label": "Im Heimgarten",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10116680,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 101336535
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 102436482,
#       "geometry": {
#         "y": 268623.5,
#         "x": 610257.0,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         610257.0,
#         268623.5,
#         610257.0,
#         268623.5
#       ],
#       "attributes": {
#         "adr_number": "10.2",
#         "com_fosnr": 2701,
#         "bdg_category": "non_residential",
#         "adr_modified": "20220325",
#         "zip_label": "4056 Basel",
#         "adr_egaid": 102436482,
#         "adr_edid": 0,
#         "label": 102436482,
#         "bdg_egid": 243057811,
#         "stn_label": "Im Davidsboden",
#         "adr_official": false,
#         "adr_status": "real",
#         "str_esid": 10179473,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 102436482
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100327839,
#       "geometry": {
#         "y": 269013.5,
#         "x": 610287.6,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         610287.6,
#         269013.5,
#         610287.6,
#         269013.5
#       ],
#       "attributes": {
#         "adr_number": "37",
#         "com_fosnr": 2701,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4056 Basel",
#         "adr_egaid": 100327839,
#         "adr_edid": 0,
#         "label": 100327839,
#         "bdg_egid": 453358,
#         "stn_label": "Hüningerstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10110167,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100327839
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100330501,
#       "geometry": {
#         "y": 266911.8,
#         "x": 610518.3,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         610518.3,
#         266911.8,
#         610518.3,
#         266911.8
#       ],
#       "attributes": {
#         "adr_number": "42a",
#         "com_fosnr": 2701,
#         "bdg_category": "partly_residential",
#         "adr_modified": "20210126",
#         "zip_label": "4051 Basel",
#         "adr_egaid": 100330501,
#         "adr_edid": 0,
#         "label": 100330501,
#         "bdg_egid": 442016,
#         "stn_label": "Burgunderstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10025349,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100330501
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100266393,
#       "geometry": {
#         "y": 268305.4,
#         "x": 613429.7,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         613429.7,
#         268305.4,
#         613429.7,
#         268305.4
#       ],
#       "attributes": {
#         "adr_number": "96",
#         "com_fosnr": 2701,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4058 Basel",
#         "adr_egaid": 100266393,
#         "adr_edid": 0,
#         "label": 100266393,
#         "bdg_egid": 455547,
#         "stn_label": "Hirzbrunnenstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10026524,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100266393
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 101371310,
#       "geometry": {
#         "y": 268451.5,
#         "x": 611276.1,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         611276.1,
#         268451.5,
#         611276.1,
#         268451.5
#       ],
#       "attributes": {
#         "adr_number": "59a",
#         "com_fosnr": 2701,
#         "bdg_category": "residential",
#         "adr_modified": "20220308",
#         "zip_label": "4057 Basel",
#         "adr_egaid": 101371310,
#         "adr_edid": 0,
#         "label": 101371310,
#         "bdg_egid": 243052726,
#         "stn_label": "Breisacherstrasse",
#         "adr_official": false,
#         "adr_status": "real",
#         "str_esid": 10026498,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 101371310
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 102437041,
#       "geometry": {
#         "y": 270371.3,
#         "x": 611572.7,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         611572.7,
#         270371.3,
#         611572.7,
#         270371.3
#       ],
#       "attributes": {
#         "adr_number": "39",
#         "com_fosnr": 2701,
#         "bdg_category": "non_residential",
#         "adr_modified": "20210126",
#         "zip_label": "4057 Basel",
#         "adr_egaid": 102437041,
#         "adr_edid": 0,
#         "label": 102437041,
#         "bdg_egid": 243016352,
#         "stn_label": "Dorfstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10064906,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 102437041
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 102437297,
#       "geometry": {
#         "y": 264617.6,
#         "x": 611525.0,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         611525.0,
#         264617.6,
#         611525.0,
#         264617.6
#       ],
#       "attributes": {
#         "adr_number": "132.1",
#         "com_fosnr": 2701,
#         "bdg_category": "non_residential",
#         "adr_modified": "20220325",
#         "zip_label": "4059 Basel",
#         "adr_egaid": 102437297,
#         "adr_edid": 0,
#         "label": 102437297,
#         "bdg_egid": 243057040,
#         "stn_label": "Bruderholzallee",
#         "adr_official": false,
#         "adr_status": "real",
#         "str_esid": 10025118,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 102437297
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 101229344,
#       "geometry": {
#         "y": 266309.9,
#         "x": 611759.4,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         611759.4,
#         266309.9,
#         611759.4,
#         266309.9
#       ],
#       "attributes": {
#         "adr_number": "47",
#         "com_fosnr": 2701,
#         "bdg_category": "non_residential",
#         "adr_modified": "20210126",
#         "zip_label": "4052 Basel",
#         "adr_egaid": 101229344,
#         "adr_edid": 0,
#         "label": 101229344,
#         "bdg_egid": 2081522,
#         "stn_label": "Peter Merian-Strasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10179465,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 101229344
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 102423193,
#       "geometry": {
#         "y": 268816.8,
#         "x": 614444.7,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         614444.7,
#         268816.8,
#         614444.7,
#         268816.8
#       ],
#       "attributes": {
#         "adr_number": "16",
#         "com_fosnr": 2703,
#         "bdg_category": "non_residential",
#         "adr_modified": "20210126",
#         "zip_label": "4125 Riehen",
#         "adr_egaid": 102423193,
#         "adr_edid": 0,
#         "label": 102423193,
#         "bdg_egid": 243022619,
#         "stn_label": "Helvetierstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10086296,
#         "com_name": "Riehen"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 102423193
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100297813,
#       "geometry": {
#         "y": 267223.2,
#         "x": 610796.2,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         610796.2,
#         267223.2,
#         610796.2,
#         267223.2
#       ],
#       "attributes": {
#         "adr_number": "4",
#         "com_fosnr": 2701,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4051 Basel",
#         "adr_egaid": 100297813,
#         "adr_edid": 0,
#         "label": 100297813,
#         "bdg_egid": 441830,
#         "stn_label": "Mostackerstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10089611,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100297813
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 102423776,
#       "geometry": {
#         "y": 269840.1,
#         "x": 615735.6,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         615735.6,
#         269840.1,
#         615735.6,
#         269840.1
#       ],
#       "attributes": {
#         "adr_number": "18.2",
#         "com_fosnr": 2703,
#         "bdg_category": "non_residential",
#         "adr_modified": "20220325",
#         "zip_label": "4125 Riehen",
#         "adr_egaid": 102423776,
#         "adr_edid": 0,
#         "label": 102423776,
#         "bdg_egid": 243054683,
#         "stn_label": "Grenzacherweg",
#         "adr_official": false,
#         "adr_status": "real",
#         "str_esid": 10026276,
#         "com_name": "Riehen"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 102423776
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100264405,
#       "geometry": {
#         "y": 269108.7,
#         "x": 616555.8,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         616555.8,
#         269108.7,
#         616555.8,
#         269108.7
#       ],
#       "attributes": {
#         "adr_number": "237",
#         "com_fosnr": 2703,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4125 Riehen",
#         "adr_egaid": 100264405,
#         "adr_edid": 0,
#         "label": 100264405,
#         "bdg_egid": 460475,
#         "stn_label": "Bettingerstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10026264,
#         "com_name": "Riehen"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100264405
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 102435482,
#       "geometry": {
#         "y": 268174.9,
#         "x": 613957.9,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         613957.9,
#         268174.9,
#         613957.9,
#         268174.9
#       ],
#       "attributes": {
#         "adr_number": "219.4",
#         "com_fosnr": 2701,
#         "bdg_category": "non_residential",
#         "adr_modified": "20220325",
#         "zip_label": "4058 Basel",
#         "adr_egaid": 102435482,
#         "adr_edid": 0,
#         "label": 102435482,
#         "bdg_egid": 243054245,
#         "stn_label": "Allmendstrasse",
#         "adr_official": false,
#         "adr_status": "real",
#         "str_esid": 10055759,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 102435482
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100287387,
#       "geometry": {
#         "y": 267893.0,
#         "x": 611442.8,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         611442.8,
#         267893.0,
#         611442.8,
#         267893.0
#       ],
#       "attributes": {
#         "adr_number": "3",
#         "com_fosnr": 2701,
#         "bdg_category": "other_residential",
#         "adr_modified": "20210126",
#         "zip_label": "4058 Basel",
#         "adr_egaid": 100287387,
#         "adr_edid": 0,
#         "label": 100287387,
#         "bdg_egid": 454153,
#         "stn_label": "Webergasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10025338,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100287387
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100332020,
#       "geometry": {
#         "y": 265141.4,
#         "x": 612405.2,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         612405.2,
#         265141.4,
#         612405.2,
#         265141.4
#       ],
#       "attributes": {
#         "adr_number": "496",
#         "com_fosnr": 2701,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4053 Basel",
#         "adr_egaid": 100332020,
#         "adr_edid": 0,
#         "label": 100332020,
#         "bdg_egid": 445565,
#         "stn_label": "Gundeldingerstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10055451,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100332020
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100326171,
#       "geometry": {
#         "y": 267642.7,
#         "x": 609711.2,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         609711.2,
#         267642.7,
#         609711.2,
#         267642.7
#       ],
#       "attributes": {
#         "adr_number": "15",
#         "com_fosnr": 2701,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4055 Basel",
#         "adr_egaid": 100326171,
#         "adr_edid": 0,
#         "label": 100326171,
#         "bdg_egid": 451587,
#         "stn_label": "St. Galler-Ring",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10088585,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100326171
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100330137,
#       "geometry": {
#         "y": 266651.5,
#         "x": 609588.3,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         609588.3,
#         266651.5,
#         609588.3,
#         266651.5
#       ],
#       "attributes": {
#         "adr_number": "175",
#         "com_fosnr": 2701,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4054 Basel",
#         "adr_egaid": 100330137,
#         "adr_edid": 0,
#         "label": 100330137,
#         "bdg_egid": 448659,
#         "stn_label": "Morgartenring",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10025038,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100330137
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100329326,
#       "geometry": {
#         "y": 267063.1,
#         "x": 612636.6,
# ...
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         610400.3,
#         268110.5,
#         610400.3,
#         268110.5
#       ],
#       "attributes": {
#         "adr_number": "83",
#         "com_fosnr": 2701,
#         "bdg_category": "other_residential",
#         "adr_modified": "20210126",
#         "zip_label": "4056 Basel",
#         "adr_egaid": 100297086,
#         "adr_edid": 0,
#         "label": 100297086,
#         "bdg_egid": 441063,
#         "stn_label": "St. Johanns-Ring",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10175160,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100297086
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100262912,
#       "geometry": {
#         "y": 268619.1,
#         "x": 611923.2,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         611923.2,
#         268619.1,
#         611923.2,
#         268619.1
#       ],
#       "attributes": {
#         "adr_number": "189",
#         "com_fosnr": 2701,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4057 Basel",
#         "adr_egaid": 100262912,
#         "adr_edid": 0,
#         "label": 100262912,
#         "bdg_egid": 457605,
#         "stn_label": "Oetlingerstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10175159,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100262912
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100322604,
#       "geometry": {
#         "y": 269565.4,
#         "x": 610080.2,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         610080.2,
#         269565.4,
#         610080.2,
#         269565.4
#       ],
#       "attributes": {
#         "adr_number": "258",
#         "com_fosnr": 2701,
#         "bdg_category": "other_residential",
#         "adr_modified": "20210126",
#         "zip_label": "4056 Basel",
#         "adr_egaid": 100322604,
#         "adr_edid": 0,
#         "label": 100322604,
#         "bdg_egid": 453423,
#         "stn_label": "Elsässerstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10088565,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100322604
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 101336664,
#       "geometry": {
#         "y": 269412.8,
#         "x": 615487.1,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         615487.1,
#         269412.8,
#         615487.1,
#         269412.8
#       ],
#       "attributes": {
#         "adr_number": "11",
#         "com_fosnr": 2703,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4125 Riehen",
#         "adr_egaid": 101336664,
#         "adr_edid": 0,
#         "label": 101336664,
#         "bdg_egid": 243023148,
#         "stn_label": "Lachenweg",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10026586,
#         "com_name": "Riehen"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 101336664
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100297391,
#       "geometry": {
#         "y": 267570.1,
#         "x": 610648.5,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         610648.5,
#         267570.1,
#         610648.5,
#         267570.1
#       ],
#       "attributes": {
#         "adr_number": "4",
#         "com_fosnr": 2701,
#         "bdg_category": "partly_residential",
#         "adr_modified": "20220124",
#         "zip_label": "4055 Basel",
#         "adr_egaid": 100297391,
#         "adr_edid": 0,
#         "label": 100297391,
#         "bdg_egid": 441348,
#         "stn_label": "Missionsstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10025933,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100297391
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 102435511,
#       "geometry": {
#         "y": 267809.6,
#         "x": 609707.7,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         609707.7,
#         267809.6,
#         609707.7,
#         267809.6
#       ],
#       "attributes": {
#         "adr_number": "114.1",
#         "com_fosnr": 2701,
#         "bdg_category": "non_residential",
#         "adr_modified": "20220325",
#         "zip_label": "4055 Basel",
#         "adr_egaid": 102435511,
#         "adr_edid": 0,
#         "label": 102435511,
#         "bdg_egid": 243055141,
#         "stn_label": "Strassburgerallee",
#         "adr_official": false,
#         "adr_status": "real",
#         "str_esid": 10087603,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 102435511
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100266180,
#       "geometry": {
#         "y": 267588.1,
#         "x": 611833.4,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         611833.4,
#         267588.1,
#         611833.4,
#         267588.1
#       ],
#       "attributes": {
#         "adr_number": "3",
#         "com_fosnr": 2701,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4058 Basel",
#         "adr_egaid": 100266180,
#         "adr_edid": 0,
#         "label": 100266180,
#         "bdg_egid": 454098,
#         "stn_label": "Kartausgasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10063535,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100266180
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100261532,
#       "geometry": {
#         "y": 268444.5,
#         "x": 611917.4,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         611917.4,
#         268444.5,
#         611917.4,
#         268444.5
#       ],
#       "attributes": {
#         "adr_number": "97",
#         "com_fosnr": 2701,
#         "bdg_category": "other_residential",
#         "adr_modified": "20210126",
#         "zip_label": "4057 Basel",
#         "adr_egaid": 100261532,
#         "adr_edid": 0,
#         "label": 100261532,
#         "bdg_egid": 457379,
#         "stn_label": "Haltingerstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10025914,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100261532
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100242951,
#       "geometry": {
#         "y": 269966.4,
#         "x": 615690.0,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         615690.0,
#         269966.4,
#         615690.0,
#         269966.4
#       ],
#       "attributes": {
#         "adr_number": "19",
#         "com_fosnr": 2703,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4125 Riehen",
#         "adr_egaid": 100242951,
#         "adr_edid": 0,
#         "label": 100242951,
#         "bdg_egid": 462088,
#         "stn_label": "Burgstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10086290,
#         "com_name": "Riehen"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100242951
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 102436040,
#       "geometry": {
#         "y": 265472.4,
#         "x": 612063.7,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         612063.7,
#         265472.4,
#         612063.7,
#         265472.4
#       ],
#       "attributes": {
#         "adr_number": "274.1",
#         "com_fosnr": 2701,
#         "bdg_category": "non_residential",
#         "adr_modified": "20220325",
#         "zip_label": "4053 Basel",
#         "adr_egaid": 102436040,
#         "adr_edid": 0,
#         "label": 102436040,
#         "bdg_egid": 243055167,
#         "stn_label": "Dornacherstrasse",
#         "adr_official": false,
#         "adr_status": "real",
#         "str_esid": 10088564,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 102436040
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100294068,
#       "geometry": {
#         "y": 265702.0,
#         "x": 611488.9,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         611488.9,
#         265702.0,
#         611488.9,
#         265702.0
#       ],
#       "attributes": {
#         "adr_number": "36",
#         "com_fosnr": 2701,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4053 Basel",
#         "adr_egaid": 100294068,
#         "adr_edid": 0,
#         "label": 100294068,
#         "bdg_egid": 444908,
#         "stn_label": "Jurastrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10026805,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100294068
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 102435483,
#       "geometry": {
#         "y": 268243.3,
#         "x": 609316.8,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         609316.8,
#         268243.3,
#         609316.8,
#         268243.3
#       ],
#       "attributes": {
#         "adr_number": "9.1",
#         "com_fosnr": 2701,
#         "bdg_category": "non_residential",
#         "adr_modified": "20220325",
#         "zip_label": "4055 Basel",
#         "adr_egaid": 102435483,
#         "adr_edid": 0,
#         "label": 102435483,
#         "bdg_egid": 243055131,
#         "stn_label": "Sundgauerstrasse",
#         "adr_official": false,
#         "adr_status": "real",
#         "str_esid": 10110182,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 102435483
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100322506,
#       "geometry": {
#         "y": 266881.9,
#         "x": 611212.5,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         611212.5,
#         266881.9,
#         611212.5,
#         266881.9
#       ],
#       "attributes": {
#         "adr_number": "21",
#         "com_fosnr": 2701,
#         "bdg_category": "other_residential",
#         "adr_modified": "20210126",
#         "zip_label": "4051 Basel",
#         "adr_egaid": 100322506,
#         "adr_edid": 0,
#         "label": 100322506,
#         "bdg_egid": 440746,
#         "stn_label": "Kohlenberggasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10181177,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100322506
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 101840959,
#       "geometry": {
#         "y": 269062.2,
#         "x": 612866.7,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         612866.7,
#         269062.2,
#         612866.7,
#         269062.2
#       ],
#       "attributes": {
#         "adr_number": "260",
#         "com_fosnr": 2701,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4058 Basel",
#         "adr_egaid": 101840959,
#         "adr_edid": 0,
#         "label": 101840959,
#         "bdg_egid": 243055953,
#         "stn_label": "In den Schorenmatten",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10063533,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 101840959
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100294328,
#       "geometry": {
#         "y": 265587.2,
#         "x": 611214.4,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         611214.4,
#         265587.2,
#         611214.4,
#         265587.2
#       ],
#       "attributes": {
#         "adr_number": "16",
#         "com_fosnr": 2701,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4053 Basel",
#         "adr_egaid": 100294328,
#         "adr_edid": 0,
#         "label": 100294328,
#         "bdg_egid": 446448,
#         "stn_label": "Röschenzerstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10110177,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100294328
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 101008212,
#       "geometry": {
#         "y": 267359.8,
#         "x": 610808.9,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         610808.9,
#         267359.8,
#         610808.9,
#         267359.8
#       ],
#       "attributes": {
#         "adr_number": "11",
#         "com_fosnr": 2701,
#         "bdg_category": "other_residential",
#         "adr_modified": "20210126",
#         "zip_label": "4051 Basel",
#         "adr_egaid": 101008212,
#         "adr_edid": 0,
#         "label": 101008212,
#         "bdg_egid": 2081069,
#         "stn_label": "Schützenmattstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10089615,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 101008212
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 102190816,
#       "geometry": {
#         "y": 264364.3,
#         "x": 612112.3,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         612112.3,
#         264364.3,
#         612112.3,
#         264364.3
#       ],
#       "attributes": {
#         "adr_number": "8",
#         "com_fosnr": 2701,
#         "bdg_category": "residential",
#         "adr_modified": "20210126",
#         "zip_label": "4059 Basel",
#         "adr_egaid": 102190816,
#         "adr_edid": 0,
#         "label": 102190816,
#         "bdg_egid": 447130,
#         "stn_label": "Bürenfluhstrasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10025119,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 102190816
#     },
#     {
#       "layerName": "Amtliches Gebäudeadressverzeichnis",
#       "featureId": 100296148,
#       "geometry": {
#         "y": 267673.2,
#         "x": 611199.8,
#         "spatialReference": {
#           "wkid": 21781
#         }
#       },
#       "bbox": [
#         611199.8,
#         267673.2,
#         611199.8,
#         267673.2
#       ],
#       "attributes": {
#         "adr_number": "6",
#         "com_fosnr": 2701,
#         "bdg_category": "other_residential",
#         "adr_modified": "20210126",
#         "zip_label": "4051 Basel",
#         "adr_egaid": 100296148,
#         "adr_edid": 0,
#         "label": 100296148,
#         "bdg_egid": 440145,
#         "stn_label": "Marktgasse",
#         "adr_official": true,
#         "adr_status": "real",
#         "str_esid": 10088575,
#         "com_name": "Basel"
#       },
#       "layerBodId": "ch.swisstopo.amtliches-gebaeudeadressverzeichnis",
#       "id": 100296148
#     }
#   ]
# }

# %%
import json
import requests
url = r"https://api3.geo.admin.ch/rest/services/profile.json"
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-73-a345878d3f9a> in <module>
#       3 url = r"https://api3.geo.admin.ch/rest/services/profile.json"
#       4 response = requests.get(url=url, params=params)
# ----> 5 response.json()
#
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     338         end = _w(s, end).end()
#     339         if end != len(s):
# --> 340             raise JSONDecodeError("Extra data", s, end)
#     341         return obj
#     342
#
# JSONDecodeError: Extra data: line 1 column 5 (char 4)
