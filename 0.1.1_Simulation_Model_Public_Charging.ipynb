# %%
import folium
import requests
import json
import os
from pandas.io.json import json_normalize
import pandas as pd


#zur Sicherheit, Directory einstellen
os.chdir(r'/Users/yannickbolli/Downloads/jupyter_notebook_daten (4)')

#JSON File für die Ladestationen als speichern
url = "https://data.geo.admin.ch/ch.bfe.ladestellen-elektromobilitaet/data/oicp/ch.bfe.ladestellen-elektromobilitaet.json"

#Daten mittels REST GET request holen
data = requests.get(url)

#Daten als JSON File speichern
data = data.json()

#Keine Ahnung, funktioniert aber mehr oder weniger
df = pd.DataFrame(data["EVSEData"]) #EVSEData
df.info
df.head(10)
df["OperatorName"]



#Ich habe hier versucht die GeoCoordinates automatisch auszulesen aus dem json.file. 
#Damit nicht all Koordinaten manuell eingetragen werden müssen
 
#f = open ('ch.bfe.ladestellen-elektromobilitaet.json', "r")
 
# Reading from file
#data = json.loads(f.read())
 
# Iterating through the json
# list
#for i in data['OperatorName']:
    #print(i)
 
# Closing file
#f.close()
 
## Closing file
#f.close()
#with open('/Users/yannickbolli/Downloads/jupyter_notebook_daten (4)/ch.bfe.ladestellen-elektromobilitaet.json', 'r') as f:
  #daten = json.load(f)
#print(daten)
# Out:
# 0     EWD Elektrizitätswerk Davos AG
# 1                              Tesla
# 2                     Martin Hertach
# 3                   Chocolat Frey AG
# 4                        PLUG’N ROLL
# 5       Elektrizitätswerk Herrliberg
# 6        Backpackers Villa Sonnenhof
# 7                     ebs Energie AG
# 8                     Stadt Dietikon
# 9                       Lidl Schweiz
# 10        Elektrizitätswerk Obwalden
# 11                              AVIA
# 12                            IONITY
# 13                  en mobilecharge
# 14                  Mobimo emobility
# 15                        Bgdi_Admin
# 16                      mobilecharge
# 17                       Swisscharge
# 18                     Test Operator
# 19                         EWAcharge
# 20                          S-Charge
# 21                               IBC
# 22                     PARK & CHARGE
# 23              Migrol Fast Charging
# 24                     PAC e-moblity
# 25                              Move
# 26                               AIL
# 27                   EVA E-Mobilität
# 28                            eCarUp
# 29                            evpass
# 30                           Fastned
# 31                             Eniwa
# 32                       PLUG’N ROLL
# Name: OperatorName, dtype: object

# %%
#Folium Library benutzten um Map anzuzeigen
#Benutzt OpenStreetMap als Vorlage (Auch andere Maps könnten angezeigt werden)
#Koordinaten zeigen die Schweiz von oben an
#Koordinaten 46.4754, 8.1355 sind geografisches Zentrum der Schweiz // zoom_start so eingestellt, dass ganze CH ersichtlich
m = folium.Map(location=[46.4754, 8.1355], zoom_start = 7)

#Zeichnet einen Kreis - Beispielrepräsenation einer Ladestation zum Beispiel

#todo: Aus dem JSON File Koordinaten von Ladestationen auslesen und diese in der Karte einzeichnen

# Davos 7 Säulen - Ein paar Spielereien für die Darstellung der Map. 

folium.Marker(location=[46.81352, 9.84591], popup =  'EWD Elektrizitätswerk Davos AG - 7 Ladestationen').add_to(m)
folium.CircleMarker(location=(46.81352, 9.84591),radius=15, fill_color='blue').add_to(m)

#folium.Circle([46.81352, 9.84591],
                    #radius=80
    #).add_to(m)

folium.Circle([46.8135, 9.84586],
                    radius=80
                   ).add_to(m)

folium.Circle([46.80008, 9.83121],
                    radius=80
                   ).add_to(m)

folium.Circle([46.800129999999996, 9.83124],
                    radius=80
                   ).add_to(m)

folium.Circle([46.79978, 9.83104],
                    radius=80
                   ).add_to(m)

folium.Circle([46.79975, 9.83108],
                    radius=80
                   ).add_to(m)

folium.Circle([46.79336, 9.82095],
                    radius=80
                   ).add_to(m)

folium.Circle([46.79327, 9.82131],
                    radius=80
                   ).add_to(m)

#Next
folium.Circle([47.418125, 8.396816],
              radius=80
             ).add_to(m)

folium.Circle([47.38635, 8.08908],
              radius=80
             ).add_to(m)

folium.Circle([46.907742, 8.394953],
              radius=80
             ).add_to(m)

folium.Circle([47.284845, 8.611227],
              radius=80
             ).add_to(m)

folium.Circle([46.68459, 7.86187],
              radius=80
             ).add_to(m)

folium.Circle([47.02106, 8.65217],
              radius=80
             ).add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_68016a6666f74dfaabaf8bc087d4afe8%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_68016a6666f74dfaabaf8bc087d4afe8%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_68016a6666f74dfaabaf8bc087d4afe8%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_68016a6666f74dfaabaf8bc087d4afe8%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B46.4754%2C%208.1355%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...
